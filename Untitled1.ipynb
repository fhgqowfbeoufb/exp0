# %% [markdown]
# EXP - Introduction to Python

# %%
#Yogesh
#PRN - 25070123128

print("Yogesh Shendage")
# Out:
# Yogesh Shendage

# %%
print(2)
# Out:
# 2

# %%
print(1,2,5)
# Out:
# 1 2 5

# %%
x=2
y={1,2,5}
z="Yogesh Shendage"

print(x,y,z,sep='\n')
# Out:
# 2
# {1, 2, 5}
# Yogesh Shendage
