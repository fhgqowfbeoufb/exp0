# %% [markdown]
# <a href="https://colab.research.google.com/github/fhgqowfbeoufb/exp0/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# yogesh
# prn 25070123128
# exp 2: study of list of python
list1=['apple','orange','cherry']
print(list1)
# Out:
# ['apple', 'orange', 'cherry']

# %%
yogesh=[2,2.5,'batman', True]
print(yogesh)
# Out:
# [2, 2.5, 'batman', True]

# %%
raju=['apple','chocolate','protein','fibre','water','milk']
print(raju[2])
print(raju[-4])
print(raju[2:5])
print(raju[:5])
print(raju[2:])
# Out:
# protein
# protein
# ['protein', 'fibre', 'water']
# ['apple', 'chocolate', 'protein', 'fibre', 'water']
# ['protein', 'fibre', 'water', 'milk']

# %%
list5=['apple','orange','cherry']
list5.append('mango')
print(list5)
# Out:
# ['apple', 'orange', 'cherry', 'mango']

# %%
list6=['apple','orange','cherry']
list6.insert(1,'mango')
print(list6)
# Out:
# ['apple', 'mango', 'orange', 'cherry']

# %%
list7=['apple','banana','orange']
list8=['kiwi','mango','cherry']
list7.extend(list8)
print(list7)
# Out:
# ['apple', 'banana', 'orange', 'kiwi', 'mango', 'cherry']

# %%
list9=['apple','orange','apple','cherry']
print(list9)
# Out:
# ['apple', 'orange', 'apple', 'cherry']

# %%
marks = [78,85,90,66,88]
print(max(marks))
print(min(marks))
print(len(marks))
print(sum(marks))
print(sum(marks)/len(marks))
marks.sort()
print(marks)

"calculate average marks"
'sort marks in ascending order'
# Out:
# 90
# 66
# 5
# 407
# 81.4
# [66, 78, 85, 88, 90]
# 'sort marks in ascending order'

# %%
Grocery=['Bread','Milk','Eggs','Cereal','Apples']
Grocery.append('Bananas')
Grocery.append('Flour')
print(Grocery)
Grocery.remove('Apples')
Grocery.remove('Bread')
print(Grocery)
# Out:
# ['Bread', 'Milk', 'Eggs', 'Cereal', 'Apples', 'Bananas', 'Flour']
# ['Milk', 'Eggs', 'Cereal', 'Bananas', 'Flour']
